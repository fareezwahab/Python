# %%
# Exception handling in Python is a mechanism that allows you to handle runtime errors,
#  or exceptions, in a controlled way, rather than letting your program crash unexpectedly.
# Python provides a way to catch errors, respond to them, and allow your program to continue
# running smoothly even if something goes wrong.

# try except finally
# try : keep that block of code inside try , which might give you an error
# except : catch that error

# Without Exception Handling

val1 = int(input('Enter First Value : '))
val2 = int(input('Enter Second Value : '))
res = val1 / val2
print('After Division :',res)
print('Rest Of The Code')
# Out:
# Enter First Value : 0
# Enter Second Value : 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-4261035881.py in <cell line: 0>()
#      12 val1 = int(input('Enter First Value : '))
#      13 val2 = int(input('Enter Second Value : '))
# ---> 14 res = val1 / val2
#      15 print('After Division :',res)
#      16 print('Rest Of The Code')
#
# ZeroDivisionError: division by zero

# %%
# With Exception Handling

try:
 val1 = int(input('Enter First Value : '))
 val2 = int(input('Enter Second Value : '))
 res = val1 / val2
 print('After Division :',res)
except:
  print('Something went wrong')
print('Rest Of The Code')
# Out:
# Enter First Value : 1
# Enter Second Value : 0
# Something went wrong
# Rest Of The Code

# %%
# With Exception Handling

try:
 val1 = int(input('Enter First Value : '))
 val2 = int(input('Enter Second Value : '))
 res = val1 / val2
 print('After Division :',res)
except Exception as e:
  print('Error: ', e)
print('Rest Of The Code')
# Out:
# Enter First Value : 1
# Enter Second Value : 0
# Error:  division by zero
# Rest Of The Code

# %%
# With Exception Handling

try:
 val1 = int(input('Enter First Value : '))
 val2 = int(input('Enter Second Value : '))
 res = val1 / val2
 print('After Division :',res)
except ZeroDivisionError as e:
  print('Error: ', e)
print('Rest Of The Code')
# Out:
# Enter First Value : 1
# Enter Second Value : 0
# Error:  division by zero
# Rest Of The Code

# %%
# define multiple exceptions
# but only one exception will work at a same time

try:
  val1 = int(input('Enter First Value : '))
  val2 = int(input('Enter Second Value : '))
  res = val1 / val2
  print('After Division :',res)
except (ZeroDivisionError,ValueError) as e:
  print('Error :',e)
print('Rest Of The Code')
# Out:
# Enter First Value : 1
# Enter Second Value : tu
# Error : invalid literal for int() with base 10: 'tu'
# Rest Of The Code

# %%
# finally keyword
# it will execute always

# Case 1 : when there is no exception

# define multiple exceptions
# but only one exception will work at a same time

try:
  val1 = int(input('Enter First Value : '))
  val2 = int(input('Enter Second Value : '))
  res = val1 / val2
  print('After Division :',res)
except (ZeroDivisionError,ValueError) as e:
  print('Error :',e)
finally:
  print('I will execute always')
print('Rest Of The Code')
# Out:
# Enter First Value : 1
# Enter Second Value : 0
# Error : division by zero
# I will execute always
# Rest Of The Code

# %%
# case 2 : when there is an exception

try:
  val1 = int(input('Enter First Value : '))
  val2 = int(input('Enter Second Value : '))
  res = val1 / val2
  print('After Division :',res)
except (ZeroDivisionError,ValueError) as e:
  print('Error :',e)
finally:
  print('I will execute always')
print('Rest Of The Code')

# %%
# Case 3 : when there is an exception but not handeled properly
try:
  val1 = int(input('Enter First Value : '))
  val2 = int(input('Enter Second Value : '))
  res = val1 / val2
  print('After Division :',res)
except ModuleNotFoundError as e:
  print('Error :',e)
finally:
  print('I will execute always')
print('Rest Of The Code')
